# %%
from  fastai import *
from fastai.vision.all import *  # fastai2.0 版本后加上all
from nbdev.showdoc import *
# Out:
# /workspace/.pip-modules/lib/python3.7/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
path = Config().data/'bears'
path.mkdir(parents=True, exist_ok=True)

# %%
print(path)
path = '/workspace/Code1/data/bears'
# Out:
# /home/gitpod/.fastai/data/bears

# %%
classes = ['teddys','grizzly','black']
for c in classes:
    print(c)
    file = f'url_{c}.txt'
    download_images(path/c, path/file, max_pics=200)
# Out:
# teddys
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-9bfc0c7534e3> in <module>
#       3     print(c)
#       4     file = f'url_{c}.csv'
# ----> 5     download_images(path/c, path/file, max_pics=200)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=0)
# Out:
# teddys
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-8c361735a113> in <module>
#       1 for c in classes:
#       2     print(c)
# ----> 3     verify_images(path/c, delete=True, max_workers=8)
#
# TypeError: verify_images() got an unexpected keyword argument 'delete'

# %%
import numpy as np
np.random.seed(42)
dls = ImageDataLoaders.from_folder(path, train=".", valid_pct=0.2, item_tfms=RandomResizedCrop(460, min_scale=0.75),
                                    bs=64, batch_tfms=[*aug_transforms(size=224, max_warp=0), Normalize.from_stats(*imagenet_stats)])
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-7-45beabcb0d50> in <module>
#       2 np.random.seed(42)
#       3 dls = ImageDataLoaders.from_folder(path, train=".", valid_pct=0.2, item_tfms=RandomResizedCrop(460, min_scale=0.75),
# ----> 4                                     bs=64, batch_tfms=[*aug_transforms(size=224, max_warp=0), Normalize.from_stats(*imagenet_stats)])
#
# /workspace/.pip-modules/lib/python3.7/site-packages/fastai/vision/data.py in from_folder(cls, path, train, valid, valid_pct, seed, vocab, item_tfms, batch_tfms, **kwargs)
#      99                            item_tfms=item_tfms,
#     100                            batch_tfms=batch_tfms)
# --> 101         return cls.from_dblock(dblock, path, path=path, **kwargs)
#     102
#     103     @classmethod
#
# ...
